# %%
import matplotlib.pyplot as plt

# %%
import h5py
import numpy as np
import matplotlib.pyplot as plt

h5_path = "/home/robot/robot_ws/egomimic/robot/demos/demo_1.hdf5"  # <- change this

with h5py.File(h5_path, "r") as f:
    # 1) load action
    cmd_actions = f["actions"]["eepose"][...]  # shape: (T, 14) based on your saver
    robot_actions = f["observations"]["eepose"][...]
    T = cmd_actions.shape[0]
    print("cmd_actions shape:", cmd_actions.shape)
    print("robot_actions shape:", robot_actions.shape)

    # left arm: 0:3 xyz, 3:6 ypr, 13 gripper
    # right arm: 7:10 xyz, 10:13 ypr, 14 gripper

    arms = ["left", "right"]
    dims = ["x", "y", "z", "roll", "pitch", "yaw", "gripper"]
    # index map
    sel = {
        "left": {
            "xyz": slice(0, 3),
            "ypr": slice(3, 6),
            "gripper": 6,
        },
        "right": {
            "xyz": slice(7, 10),
            "ypr": slice(10, 13),
            "gripper": 13,
        },
    }

    # ---- plot for each arm, each variable ---
    for arm in arms:
        fig, axs = plt.subplots(7, 1, figsize=(12, 14), sharex=True)
        fig.suptitle(
            f"{arm.capitalize()} Arm: Commanded vs Robot (xyz, roll, pitch, yaw, gripper)"
        )

        # xyz
        for i, label in enumerate(["x", "y", "z"]):
            axs[i].plot(
                np.arange(T), cmd_actions[:, sel[arm]["xyz"].start + i], label="cmd"
            )
            axs[i].plot(
                np.arange(T), robot_actions[:, sel[arm]["xyz"].start + i], label="robot"
            )
            axs[i].set_ylabel(label)
            axs[i].legend(loc="upper right")
            axs[i].set_title(f"{label} position")

        # roll, pitch, yaw (note: these are YPR, so roll=y, pitch=p, yaw=r)
        for j, label in enumerate(["roll", "pitch", "yaw"]):
            axs[3 + j].plot(
                np.arange(T), cmd_actions[:, sel[arm]["ypr"].start + j], label="cmd"
            )
            axs[3 + j].plot(
                np.arange(T), robot_actions[:, sel[arm]["ypr"].start + j], label="robot"
            )
            axs[3 + j].set_ylabel(label)
            axs[3 + j].legend(loc="upper right")
            axs[3 + j].set_title(f"{label} (rad)")

        # gripper
        axs[6].plot(np.arange(T), cmd_actions[:, sel[arm]["gripper"]], label="cmd")
        axs[6].plot(np.arange(T), robot_actions[:, sel[arm]["gripper"]], label="robot")
        axs[6].set_ylabel("gripper")
        axs[6].legend(loc="upper right")
        axs[6].set_title("Gripper")

        axs[-1].set_xlabel("timestep")
        plt.tight_layout()
        plt.show()

    # ---- show images ----
    cam_group = f["observations"]["images"]
    cam_names = list(cam_group.keys())
    print("cams:", cam_names)

    # 3) sample a few timesteps to show images
    timesteps_to_show = [0, min(10, T - 1), T - 1]  # first, 10th, last

    for cam in cam_names:
        imgs = cam_group[cam]  # (T, 480, 640, 3)
        print(f"{cam} shape:", imgs.shape)

        fig, axs = plt.subplots(
            1, len(timesteps_to_show), figsize=(4 * len(timesteps_to_show), 4)
        )
        if len(timesteps_to_show) == 1:
            axs = [axs]
        for j, t in enumerate(timesteps_to_show):
            axs[j].imshow(imgs[t])
            axs[j].set_title(f"{cam} @ t={t}")
            axs[j].axis("off")
        plt.show()
# Out:
# cmd_actions shape: (582, 14)
# robot_actions shape: (582, 14)
# cams: ['front_img_1', 'right_wrist_img']
# front_img_1 shape: (582, 480, 640, 3)
# right_wrist_img shape: (582, 480, 640, 3)

# %%
import h5py
import os
from PIL import Image  # pillow

h5_path = "/home/robot/robot_ws/egomimic/robot/demos/demo_1.hdf5"  # change
out_dir = "./frames"
os.makedirs(out_dir, exist_ok=True)

with h5py.File(h5_path, "r") as f:
    img_grp = f["observations"]["images"]
    cam_names = list(img_grp.keys())
    print("cams:", cam_names)

    for cam in cam_names:
        frames = img_grp[cam]  # (T, H, W, 3), uint8, RGB
        T = frames.shape[0]
        for i in range(T):
            rgb = frames[i]  # numpy array
            img = Image.fromarray(rgb)  # RGB already
            fname = os.path.join(out_dir, f"{cam}_{i:05d}.png")
            img.save(fname)

print(f"saved frames to {out_dir}")
# Out:
# cams: ['front_img_1', 'left_wrist_img']
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File /usr/local/lib/python3.10/dist-packages/PIL/ImageFile.py:648, in _save(im, fp, tile, bufsize)
#     647 try:
# --> 648     fh = fp.fileno()
#     649     fp.flush()
#
# AttributeError: '_idat' object has no attribute 'fileno'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 21
#      19             img = Image.fromarray(rgb)  # RGB already
#      20             fname = os.path.join(out_dir, f"{cam}_{i:05d}.png")
# ---> 21             img.save(fname)
#      23 print(f"saved frames to {out_dir}")
#
# File /usr/local/lib/python3.10/dist-packages/PIL/Image.py:2571, in Image.save(self, fp, format, **params)
#    2568     fp = cast(IO[bytes], fp)
#    2570 try:
# -> 2571     save_handler(self, fp, filename)
#    2572 except Exception:
#    2573     if open_fp:
#
# File /usr/local/lib/python3.10/dist-packages/PIL/PngImagePlugin.py:1497, in _save(im, fp, filename, chunk, save_all)
#    1493     single_im = _write_multiple_frames(
#    1494         im, fp, chunk, mode, rawmode, default_image, append_images
#    1495     )
#    1496 if single_im:
# -> 1497     ImageFile._save(
#    1498         single_im,
#    1499         cast(IO[bytes], _idat(fp, chunk)),
#    1500         [ImageFile._Tile("zip", (0, 0) + single_im.size, 0, rawmode)],
#    1501     )
#    1503 if info:
#    1504     for info_chunk in info.chunks:
#
# File /usr/local/lib/python3.10/dist-packages/PIL/ImageFile.py:652, in _save(im, fp, tile, bufsize)
#     650     _encode_tile(im, fp, tile, bufsize, fh)
#     651 except (AttributeError, io.UnsupportedOperation) as exc:
# --> 652     _encode_tile(im, fp, tile, bufsize, None, exc)
#     653 if hasattr(fp, "flush"):
#     654     fp.flush()
#
# File /usr/local/lib/python3.10/dist-packages/PIL/ImageFile.py:678, in _encode_tile(im, fp, tile, bufsize, fh, exc)
#     675 if exc:
#     676     # compress to Python file-compatible object
#     677     while True:
# --> 678         errcode, data = encoder.encode(bufsize)[1:]
#     679         fp.write(data)
#     680         if errcode:
#
# KeyboardInterrupt:

# %%
import torch
import numpy as np
from egomimic.utils.egomimicUtils import CameraTransforms, draw_actions
import torchvision.io as io
from egomimic.robot.eva.eva_kinematics import EvaMinkKinematicsSolver

kinematics_solver = EvaMinkKinematicsSolver(model_path="/home/robot/robot_ws/egomimic/resources/model_x5.xml")

def visualize_actions(ims, actions, extrinsics, intrinsics, arm="both"):
    if actions.shape[-1] == 7 or actions.shape[-1] == 14:
        ac_type = "joints"
    elif actions.shape[-1] == 3 or actions.shape[-1] == 6:
        ac_type = "xyz"
    else:
        raise ValueError(f"Unknown action type with shape {actions.shape}")
    print(arm)
    ims = draw_actions(
        ims, ac_type, "Purples", actions, extrinsics, intrinsics, arm=arm, kinematics_solver=kinematics_solver
    )

    return ims
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 7
#       4 import torchvision.io as io
#       5 from egomimic.robot.eva.eva_kinematics import EvaMinkKinematicsSolver
# ----> 7 kinematics_solver = EvaMinkKinematicsSolver()
#       9 def visualize_actions(ims, actions, extrinsics, intrinsics, arm="both"):
#      10     if actions.shape[-1] == 7 or actions.shape[-1] == 14:
#
# TypeError: EvaMinkKinematicsSolver.__init__() missing 1 required positional argument: 'model_path'

# %%
# Corrected action visualization and saving
import os
import h5py
import numpy as np
import torch
import torchvision.io as io
from egomimic.utils.egomimicUtils import CameraTransforms

h5_path = "/home/robot/robot_ws/egomimic/robot/demos/calibrate_right/demo_0.hdf5"
save_dir = "./visualization/"
os.makedirs(save_dir, exist_ok=True)

camera_transforms = CameraTransforms(intrinsics_key="base", extrinsics_key="x5Nov18_3")
arm = "left"
start_index = 0 if arm == "left" else 7

with h5py.File(h5_path, "r") as f:
    images = f["observations"]["images"]["front_img_1"]          # (T, H, W, 3) uint8 RGB
    actions = f["action"]  # (T, 3)
    every_nth = 15
    nth_image = images[::every_nth]
    for i, im in enumerate(nth_image):
        # Build batch of size 1 for visualize_actions
        action_seq = actions[i * every_nth : min(i * every_nth + 100, actions.shape[0])]                   # (1, 3)

        im_viz = visualize_actions(
            im,
            action_seq,
            camera_transforms.extrinsics,
            camera_transforms.intrinsics,
            arm=arm,
        )
        # Save the visualized image
        img_tensor = torch.from_numpy(im_viz).permute(2, 0, 1).contiguous()
        io.write_png(img_tensor, os.path.join(save_dir, f"image_{i * every_nth}.png"))

        print(f"Saved image {i * every_nth} with overlays to {save_dir}")
# Out:
# left
# Saved image 0 with overlays to ./visualization/
# left
# Saved image 15 with overlays to ./visualization/
# left
# Saved image 30 with overlays to ./visualization/
# left
# Saved image 45 with overlays to ./visualization/
# left
# Saved image 60 with overlays to ./visualization/
# left
# Saved image 75 with overlays to ./visualization/
# left
# Saved image 90 with overlays to ./visualization/
# left
# Saved image 105 with overlays to ./visualization/
# left
# Saved image 120 with overlays to ./visualization/
# left
# Saved image 135 with overlays to ./visualization/
# left
# Saved image 150 with overlays to ./visualization/
# left
# Saved image 165 with overlays to ./visualization/
# left
# Saved image 180 with overlays to ./visualization/
# left
# Saved image 195 with overlays to ./visualization/
# left
# Saved image 210 with overlays to ./visualization/
# left
# Saved image 225 with overlays to ./visualization/
# left
# Saved image 240 with overlays to ./visualization/
# left
# Saved image 255 with overlays to ./visualization/
# left
# Saved image 270 with overlays to ./visualization/
# left
# Saved image 285 with overlays to ./visualization/
# left
# Saved image 300 with overlays to ./visualization/
# left
# Saved image 315 with overlays to ./visualization/
# left
# Saved image 330 with overlays to ./visualization/
# left
# Saved image 345 with overlays to ./visualization/
# left
# Saved image 360 with overlays to ./visualization/
# left
# Saved image 375 with overlays to ./visualization/
# left
# Saved image 390 with overlays to ./visualization/
# left
# Saved image 405 with overlays to ./visualization/
# left
# Saved image 420 with overlays to ./visualization/
# left
# Saved image 435 with overlays to ./visualization/
# left
# Saved image 450 with overlays to ./visualization/
# left
# Saved image 465 with overlays to ./visualization/
# left
# Saved image 480 with overlays to ./visualization/
# left
# Saved image 495 with overlays to ./visualization/
# left
# Saved image 510 with overlays to ./visualization/
# left
# Saved image 525 with overlays to ./visualization/
# left
# Saved image 540 with overlays to ./visualization/
# left
# Saved image 555 with overlays to ./visualization/
# left
# Saved image 570 with overlays to ./visualization/
# left
# Saved image 585 with overlays to ./visualization/
# left
# Saved image 600 with overlays to ./visualization/
# left
# Saved image 615 with overlays to ./visualization/
# left
# Saved image 630 with overlays to ./visualization/
# left
# Saved image 645 with overlays to ./visualization/
# left
# Saved image 660 with overlays to ./visualization/
# left
# Saved image 675 with overlays to ./visualization/
# left
# Saved image 690 with overlays to ./visualization/
# left
# Saved image 705 with overlays to ./visualization/
# left
# Saved image 720 with overlays to ./visualization/
# left
# Saved image 735 with overlays to ./visualization/
# left
# Saved image 750 with overlays to ./visualization/
# left
# Saved image 765 with overlays to ./visualization/
# left
# Saved image 780 with overlays to ./visualization/
# left
# Saved image 795 with overlays to ./visualization/
# left
# Saved image 810 with overlays to ./visualization/
# left
# Saved image 825 with overlays to ./visualization/
# left
# Saved image 840 with overlays to ./visualization/
# left
# Saved image 855 with overlays to ./visualization/
# left
# Saved image 870 with overlays to ./visualization/
# left
# Saved image 885 with overlays to ./visualization/
# left
# Saved image 900 with overlays to ./visualization/
# left
# Saved image 915 with overlays to ./visualization/
# left
# Saved image 930 with overlays to ./visualization/
# left
# Saved image 945 with overlays to ./visualization/
# left
# Saved image 960 with overlays to ./visualization/
# left
# Saved image 975 with overlays to ./visualization/
# left
# Saved image 990 with overlays to ./visualization/
# left
# Saved image 1005 with overlays to ./visualization/
# left
# Saved image 1020 with overlays to ./visualization/
# left
# Saved image 1035 with overlays to ./visualization/
# left
# Saved image 1050 with overlays to ./visualization/
# left
# Saved image 1065 with overlays to ./visualization/
# left
# Saved image 1080 with overlays to ./visualization/
# left
# Saved image 1095 with overlays to ./visualization/
# left
# Saved image 1110 with overlays to ./visualization/
# left
# Saved image 1125 with overlays to ./visualization/
# left
# Saved image 1140 with overlays to ./visualization/
# left
# Saved image 1155 with overlays to ./visualization/
# left
# Saved image 1170 with overlays to ./visualization/
# left
# Saved image 1185 with overlays to ./visualization/
# left
# Saved image 1200 with overlays to ./visualization/
# left
# Saved image 1215 with overlays to ./visualization/
# left
# Saved image 1230 with overlays to ./visualization/
# left
# Saved image 1245 with overlays to ./visualization/
# left
# Saved image 1260 with overlays to ./visualization/
# left
# Saved image 1275 with overlays to ./visualization/
# left
# Saved image 1290 with overlays to ./visualization/
# left
# Saved image 1305 with overlays to ./visualization/
# left
# Saved image 1320 with overlays to ./visualization/
# left
# Saved image 1335 with overlays to ./visualization/
# left
# Saved image 1350 with overlays to ./visualization/
# left
# Saved image 1365 with overlays to ./visualization/
# left
# Saved image 1380 with overlays to ./visualization/
# left
# Saved image 1395 with overlays to ./visualization/
# left
# Saved image 1410 with overlays to ./visualization/
# left
# Saved image 1425 with overlays to ./visualization/
# left
# Saved image 1440 with overlays to ./visualization/
# left
# Saved image 1455 with overlays to ./visualization/
# left
# Saved image 1470 with overlays to ./visualization/
# left
# Saved image 1485 with overlays to ./visualization/
# left
# Saved image 1500 with overlays to ./visualization/
# left
# Saved image 1515 with overlays to ./visualization/
# left
# Saved image 1530 with overlays to ./visualization/

# %%
# Corrected action visualization and saving
import os
import h5py
import numpy as np
import torch
import torchvision.io as io
from egomimic.utils.egomimicUtils import CameraTransforms

h5_path = "/home/robot/robot_ws/egomimic/robot/calibration_demos/left/demo_1.hdf5"
save_dir = "./visualization_base/"
os.makedirs(save_dir, exist_ok=True)

camera_transforms = CameraTransforms(intrinsics_key="base", extrinsics_key="x5Nov15_2")
arm = "left"
start_index = 0 if arm == "left" else 7

with h5py.File(h5_path, "r") as f:
    images = f["observations"]["images"]["front_img_1"]          # (T, H, W, 3) uint8 RGB
    actions = f["observations"]["eepose"][:, start_index:start_index+3]  # (T, 3)
    every_nth = 15
    nth_image = images[::every_nth]
    for i, im in enumerate(nth_image):
        # Build batch of size 1 for visualize_actions
        action_seq = actions[i * every_nth : min(i * every_nth + 100, actions.shape[0])]                   # (1, 3)

        im_viz = visualize_actions(
            im,
            action_seq,
            camera_transforms.extrinsics,
            camera_transforms.intrinsics,
            arm=arm,
        )
        # Save the visualized image
        img_tensor = torch.from_numpy(im_viz).permute(2, 0, 1).contiguous()
        io.write_png(img_tensor, os.path.join(save_dir, f"image_{i * every_nth}.png"))

        print(f"Saved image {i * every_nth} with overlays to {save_dir}")
# Out:
# Saved image 0 with overlays to ./visualization_base/
# Saved image 15 with overlays to ./visualization_base/
# Saved image 30 with overlays to ./visualization_base/
# Saved image 45 with overlays to ./visualization_base/
# Saved image 60 with overlays to ./visualization_base/
# Saved image 75 with overlays to ./visualization_base/
# Saved image 90 with overlays to ./visualization_base/
# Saved image 105 with overlays to ./visualization_base/
# Saved image 120 with overlays to ./visualization_base/
# Saved image 135 with overlays to ./visualization_base/
# Saved image 150 with overlays to ./visualization_base/
# Saved image 165 with overlays to ./visualization_base/
# Saved image 180 with overlays to ./visualization_base/
# Saved image 195 with overlays to ./visualization_base/
# Saved image 210 with overlays to ./visualization_base/
# Saved image 225 with overlays to ./visualization_base/
# Saved image 240 with overlays to ./visualization_base/
# Saved image 255 with overlays to ./visualization_base/
# Saved image 270 with overlays to ./visualization_base/
# Saved image 285 with overlays to ./visualization_base/
# Saved image 300 with overlays to ./visualization_base/
# Saved image 315 with overlays to ./visualization_base/
# Saved image 330 with overlays to ./visualization_base/
# Saved image 345 with overlays to ./visualization_base/
# Saved image 360 with overlays to ./visualization_base/
# Saved image 375 with overlays to ./visualization_base/
# Saved image 390 with overlays to ./visualization_base/
# Saved image 405 with overlays to ./visualization_base/
# Saved image 420 with overlays to ./visualization_base/
# Saved image 435 with overlays to ./visualization_base/
# Saved image 450 with overlays to ./visualization_base/
# Saved image 465 with overlays to ./visualization_base/
# Saved image 480 with overlays to ./visualization_base/
# Saved image 495 with overlays to ./visualization_base/
# Saved image 510 with overlays to ./visualization_base/
# Saved image 525 with overlays to ./visualization_base/
# Saved image 540 with overlays to ./visualization_base/
# Saved image 555 with overlays to ./visualization_base/
# Saved image 570 with overlays to ./visualization_base/
# Saved image 585 with overlays to ./visualization_base/
# Saved image 600 with overlays to ./visualization_base/
# Saved image 615 with overlays to ./visualization_base/
# Saved image 630 with overlays to ./visualization_base/
# Saved image 645 with overlays to ./visualization_base/
# Saved image 660 with overlays to ./visualization_base/
# Saved image 675 with overlays to ./visualization_base/
# Saved image 690 with overlays to ./visualization_base/
# Saved image 705 with overlays to ./visualization_base/
# Saved image 720 with overlays to ./visualization_base/
# Saved image 735 with overlays to ./visualization_base/
# Saved image 750 with overlays to ./visualization_base/
# Saved image 765 with overlays to ./visualization_base/
# Saved image 780 with overlays to ./visualization_base/
# Saved image 795 with overlays to ./visualization_base/
# Saved image 810 with overlays to ./visualization_base/
# Saved image 825 with overlays to ./visualization_base/
# Saved image 840 with overlays to ./visualization_base/
# Saved image 855 with overlays to ./visualization_base/
# Saved image 870 with overlays to ./visualization_base/
# Saved image 885 with overlays to ./visualization_base/
# Saved image 900 with overlays to ./visualization_base/
# Saved image 915 with overlays to ./visualization_base/
# Saved image 930 with overlays to ./visualization_base/
# Saved image 945 with overlays to ./visualization_base/
# Saved image 960 with overlays to ./visualization_base/
# Saved image 975 with overlays to ./visualization_base/
# Saved image 990 with overlays to ./visualization_base/
# Saved image 1005 with overlays to ./visualization_base/
# Saved image 1020 with overlays to ./visualization_base/
# Saved image 1035 with overlays to ./visualization_base/
# Saved image 1050 with overlays to ./visualization_base/
# Saved image 1065 with overlays to ./visualization_base/
# Saved image 1080 with overlays to ./visualization_base/
# Saved image 1095 with overlays to ./visualization_base/
# Saved image 1110 with overlays to ./visualization_base/
# Saved image 1125 with overlays to ./visualization_base/
# Saved image 1140 with overlays to ./visualization_base/
# Saved image 1155 with overlays to ./visualization_base/
# Saved image 1170 with overlays to ./visualization_base/
# Saved image 1185 with overlays to ./visualization_base/
# Saved image 1200 with overlays to ./visualization_base/
# Saved image 1215 with overlays to ./visualization_base/
# Saved image 1230 with overlays to ./visualization_base/
# Saved image 1245 with overlays to ./visualization_base/
# Saved image 1260 with overlays to ./visualization_base/
